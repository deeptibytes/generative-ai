# %% [markdown]
# #### Prompt Chain With Langchain And Open AI
#
# In will demo how we will:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Create a prompt chain and invoke llm
# - Parse llm output with parser
# - LangChain Expression Language (LCEL)

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
## Create llm Langchain OpenAI Chat model
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x10d3d0400> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x10deeb820> model_name='gpt-4o' openai_api_key=SecretStr('**********') openai_proxy=''

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert Java Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are an expert Java Engineer. Provide me answers based on the questions')), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}'))])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about lambdas in Java?"})
type(response)
print(response)
# Out:
# content='Certainly! Lambdas, introduced in Java 8, are a feature that allows you to write more concise and readable code by expressing instances of single-method interfaces (functional interfaces) using a compact syntax. They are essentially anonymous functions, which means they do not have a name or belong to any class.\n\n### Key Features of Lambdas:\n\n1. **Syntax**: The lambda expression syntax consists of a parameter list, an arrow token (`->`), and a body. The body can be either an expression or a block of code.\n\n   ```java\n   (parameters) -> expression\n   (parameters) -> { statements; }\n   ```\n\n   Example:\n   ```java\n   (int x, int y) -> x + y\n   ```\n\n2. **Functional Interfaces**: Lambdas are associated with functional interfaces. A functional interface is an interface with a single abstract method. Java 8 introduced several built-in functional interfaces in the `java.util.function` package, such as `Predicate`, `Function`, `Consumer`, and `Supplier`.\n\n   Example
# ...

# %%
## stroutput Parser demo

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Stream API in Java?"})
print(response)
# Out:
# The Stream API in Java is a powerful feature that was introduced in Java 8 as part of the java.util.stream package. It is designed to process sequences of elements, such as collections, in a functional style. The Stream API allows developers to perform operations on collections of data in a declarative manner, which can lead to more readable and concise code.
#
# Here are some key features and concepts of the Stream API:
#
# 1. **Streams are not data structures**: They do not store data; instead, they carry values from a source (such as a collection, array, or I/O channel) through a pipeline of operations.
#
# 2. **Functional in nature**: Streams are designed for functional-style operations, allowing developers to write more expressive and concise code.
#
# 3. **Lazy evaluation**: Operations on streams are lazy; they are not executed until a terminal operation is invoked. This allows for optimization and can improve performance by avoiding unnecessary computations.
#
# ...
